# %% [markdown]
# ### 4 Random Strains

# %%
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

import pickle

# %%
#a random dataframe with 4 yeast strains (assume you isolated these strains for beer production)

samples = pd.read_csv('../data/all_data_13.csv',index_col=0)
samples = samples.sample(n=4)
filename_sample = '../data/predictions/samples.csv'
samples.to_csv(filename_sample, index=True)
proteins_measured = samples.iloc[:,0:725] #from 0 to 725 are ORFs (proteins), from 726 to 738 are the metabolites
proteins_measured.index = ['Strain1', 'Strain2', 'Strain3', 'Strain4']
filename_example = '../data/predictions/example.csv'
proteins_measured.to_csv(filename_example, index=True)

# %%
proteins_measured
# Out:
#           YAL003W   YAL005C   YAL007C   YAL012W   YAL035W    YAL038W  \
# Strain1  8.796518  8.361978  4.898674  8.835167  5.762265  10.301533
# Strain2  8.348643  8.326936  5.291320  9.091044  4.289959  10.100150
# Strain3  8.543367  8.658520  4.908537  8.944424  4.099228   9.617601
# Strain4  8.613005  8.619785  4.678318  8.931483  4.404717   9.753104
#
#           YAL042W   YAL044C  YAR002C-A   YAR007C  ...   YPR118W   YPR129W  \
# Strain1  4.305765  7.095703   6.343501  5.545069  ...  5.097418  5.450436
# Strain2  4.153375  7.247800   6.231253  5.434508  ...  4.950146  6.010000
# Strain3  4.129039  7.066174   6.640824  5.334720  ...  4.177657  5.897280
# Strain4  4.155136  6.878292   6.302498  5.360168  ...  4.185009  5.789836
#
#           YPR133C   YPR145W   YPR160W   YPR163C   YPR165W   YPR181C   YPR183W  \
# Strain1  3.762544  6.385688  5.094573  6.534564  6.580154  5.915176  6.963652
# Strain2  3.192102  6.450322  5.033989  6.234389  6.606676  6.071162  7.329732
# ...
